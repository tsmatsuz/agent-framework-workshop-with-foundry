# %% [markdown]
# # Lesson 8 : Workflows
#
# Up until now, we have built a single agent with language models, tools, and messages.<br>
# This type of agent essentially performs to call LLMs or tools until it reaches to the goal - such as, [ReAct](https://tsmatz.wordpress.com/2023/03/07/react-with-openai-gpt-and-langchain/)-style pattern. (See the left side in below picture.) But various processing patterns (such as, workflow pattern, fan-out/fan-in pattern, etc) or the mixture of these patterns will be required in production.
#
# ![Flow patterns](./assets/flow_patterns.png)
#
# > Note : Especially in complex tasks, cramming all the process into a single agent will result into poor performance.
# > By dividing the roles among multiple agents and collaborating these blocks, the context becomes clear, and accuracy is then expected to improve. (Also, manageability will be improved.)
#
# Using built-in process builders in Agent Framework, you can build various processing patterns to orchestrate your existing agents and custom code.
# ```WorkflowBuilder``` is a generic builder for a flexible workflow graph, and other builders (```SequentialBuilder```, ```ConcurrentBuilder```, ```GroupChatBuilder```, ```HandoffBuilder```, and ```MagenticBuilder``` - which are all built with ```WorkflowBuilder```) handles a variety of processing design patterns depending on your needs.
#
# In this exercise, we explore fundamental workflow's capabilities in Agent Framework using the following brief sequential flow.
#
# 1. Create a plan for the trip.
# 2. Revise the generated plan.
#
# > Note : Learning a variety of multi-agent design patterns (orchestration patterns) is out of scope in this repository. (See [official document](https://learn.microsoft.com/en-us/azure/architecture/ai-ml/guide/ai-agent-design-patterns) for this topic.)

# %% [markdown]
# ## 1. Build and run a simple workflow
#
# In this example, we build a workflow with generic ```WorkflowBuilder``` class in order to understand how it works internally.
#
# > Note : You can easily build this type of simple sequential flows with built-in ```SequentialBuilder``` class (instead of generic ```WorkflowBuilder```), but we don't use this high-level class for your learning purpose.

# %% [markdown]
# First we initialize the client as usual.

# %%
from dotenv import load_dotenv
from agent_framework.foundry import FoundryChatClient
from azure.identity.aio import AzureCliCredential

load_dotenv()

credential = AzureCliCredential()
client = FoundryChatClient(credential=credential)

# %% [markdown]
# Now let's build a workflow and run as follows.
#
# In workflow on Agent Framework, first we instantiate ```Executor``` (including ```Agent```) as building blocks.
# In this example, we use the following 3 executor instances - two is ```AgentExecutor``` and one is generic ```Executor```.
#
# - planning_agent : This is an executor by LLM agent to generate a plan.
# - revise_agent : This is an executor by LLM agent to revise a plan.
# - response_generator : This executor generates the final response and finalize the workflow. (The workflow instance becomes idle state after this executor is run.) In this example, it returns a list of all messages for the final response.
#
# As you can see in below code, a generic ```Executor``` is processed in a class method (function) decorated by ```@handler```. (In a single ```Executor```, you can also define multiple handlers depending on arguments.)
# All executors are connected by workflow context (the argument ```ctx``` in this code), and you can pass result (output) to another executor by using context. (See code in the following ```generate_final_respose()``` handler.)
#
# > Note : It is not recommended to split a simple task into multiple agents, because it might degrade performance.
# > Please avoid overusing multi-agents. (This is for demo purpose.)

# %%
from agent_framework import Agent, Message
from agent_framework import (
    WorkflowBuilder,
    Executor,
    AgentExecutorResponse,
    WorkflowContext,
    handler
)

class ResponseGenerator(Executor):
    @handler
    async def generate_final_respose(
        self,
        response: AgentExecutorResponse,
        ctx: WorkflowContext[list[Message]]
    ) -> None:
        # in this example, we send full conversation as a final result.
        await ctx.yield_output(list(response.full_conversation))

# instantiate executor
response_generator = ResponseGenerator(id="final_response_generator")
planning_agent = Agent(
    name="PlanningAgent",
    client=client,
    instructions="Your task is to help users plan and concisely summarize it in five bullet points.",
)
revise_agent = Agent(
    name="ReviseAgent",
    client=client,
    instructions="Your task is to review the plan you receive and to refine it further.",
)

# build workflow
workflow = (
    WorkflowBuilder(start_executor=planning_agent)
    .add_edge(planning_agent, revise_agent)
    .add_edge(revise_agent, response_generator)
    .build()
)

# run workflow
events = await workflow.run("Create a plan for my travel in Osaka.")

# %% [markdown]
# Now we output the returned result (all messages in this example) as follows.

# %%
from agent_framework import Role

outputs = events.get_outputs()
messages = outputs[2]
for i, (msg) in enumerate(messages, start=1):
    author_name = msg.author_name
    if author_name is None:
        author_name = "assistant" if msg.role == "assistant" else "user"
    print("----------------------------------")
    print(f"[{i:02d}: {author_name}]")
    print(msg.text)
# Out:
# ----------------------------------
# [01: user]
# Create a plan for my travel in Osaka.
# ----------------------------------
# [02: PlanningAgent]
# - **Set your trip basics:** Choose travel dates/length, arrival airport (KIX/ITM), neighborhood to stay (Namba/Umeda/Shin-Osaka), and daily pace (relaxed vs packed).
# - **Core Osaka sights (2–3 days):** Dotonbori & Shinsaibashi, Osaka Castle area, Umeda (Sky Building/Hep Five), Kuromon Market, and a night view/food crawl.
# - **Food-focused plan:** Must-tries (takoyaki, okonomiyaki, kushikatsu, ramen), pick 1–2 “food hubs” per day (Namba, Shinsekai, Tenma), and reserve any high-demand spots.
# - **Day trips to add (1–3 days):** Kyoto (temples + Gion), Nara (deer + Todaiji), Kobe (harbor + beef), or Himeji (castle) based on your interests.
# - **Logistics & bookings:** Get an ICOCA card, map routes on Google Maps, consider passes only if they save money, prebook Universal Studios Japan/teamsLabs? (if relevant), and keep a weather backup plan (aquarium, museums, shopping).
# ----------------------------------
# [03: ReviseAgent]
# - **Trip framework:** Pick dates/length, arrival (KIX/ITM), and base area (Namba = nightlife/food, Umeda = shopping/transport, Shin-Osaka = easy day trips).
# - **Osaka highlights (2–3 days):** Dotonbori + Shinsaibashi, Kuromon Market, Osaka Castle area, Umeda Sky Building/night view, Shinsekai (Tsutenkaku) + riverside walk.
# - **Food plan:** Build each day around one food district (Namba, Tenma, Shinsekai) and target local staples (takoyaki, okonomiyaki, kushikatsu, ramen); reserve any “must” restaurants.
# - **Add 1–3 day trips:** Kyoto (shrines/streets), Nara (Todaiji + park), Kobe (harbor + beef), Himeji (castle), based on your interests.
# - **Logistics & bookings:** Get an ICOCA card, map routes, compare rail/passes only if you’ll do multiple long rides, and prebook popular tickets (USJ, timed-entry attractions) with a rainy-day backup list.

# %% [markdown]
# ## 2. Run workflow with streaming
#
# You can also run workflow with streaming.
# Especially when you handle checkpointing (pause/resume), human-in-the-loop (HITL), etc, this might be useful. (These topics will be discussed later.)

# %%
async for event in workflow.run("Create a plan for my travel in Osaka.", stream=True):
    print(f"[{event}]")
# Out:
# [WorkflowStartedEvent(origin=WorkflowEventSource.FRAMEWORK, data=None)]
# [WorkflowStatusEvent(state=WorkflowRunState.IN_PROGRESS, data=None, origin=WorkflowEventSource.FRAMEWORK)]
# [ExecutorInvokedEvent(executor_id=PlanningAgent, data=Create a plan for my travel in Osaka.)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=Trip)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= setup)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=today)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=):)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Pick)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= dates)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=/)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=number)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= of)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= days)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=,)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= arrival)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=K)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=IX)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=/)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=IT)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=M)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=),)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= budget)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=,)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= and)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= where)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= to)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= stay)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=N)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=amba)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= =)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= food)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=/night)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=life)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=,)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= U)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=med)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=a)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= =)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= convenient)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= transit)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=,)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Shin)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=Os)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=aka)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= =)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= sh)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ink)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ansen)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= access)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=).)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=
# )]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=Day)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= )]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=1)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= –)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Min)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ami)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=N)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=amba)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=):)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Ku)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=rom)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=on)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Market)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=mor)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ning)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=))]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Sh)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=insa)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ib)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ashi)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= shopping)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= D)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=oton)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=bor)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=i)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= at)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= night)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=can)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=al)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= walk)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= +)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= street)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= food)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=).)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=
# )]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=Day)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= )]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=2)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= –)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Castle)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= +)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Kita)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=U)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=med)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=a)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=):)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Osaka)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Castle)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= &)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= park)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Ten)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=jin)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=bash)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=isu)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ji)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= shot)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=eng)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ai)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= U)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=med)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=a)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Sky)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Building)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= /)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= nightlife)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= around)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= U)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=med)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=a)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=.)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=
# )]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=Day)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= )]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=3)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= –)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Culture)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= &)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= views)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=:**)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Sh)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=iten)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=no)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ji)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Temple)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Shin)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=sek)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ai)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=k)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ush)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ik)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=atsu)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=))]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= A)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ben)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=o)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Har)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ukas)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= observ)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=atory)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=sun)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=set)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=).)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=
# )]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=Day)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= )]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=4)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=+)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= –)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Add)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=-on)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= day)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=(s)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=):)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Universal)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Studios)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Japan)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=or)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Aquarium)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=Kai)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=y)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ukan)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=))]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= +)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Tempo)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=zan)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=;)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= optional)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= day)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= trips)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=:)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Kyoto)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=,)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= N)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ara)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=,)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= Kobe)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=,)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= or)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= H)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ime)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=ji)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=choose)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= )]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=1)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= per)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages= day)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=).)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=PlanningAgent, messages=)]
# [WorkflowOutputEvent(data=- **Trip setup (today):** Pick dates/number of days, arrival (KIX/ITM), budget, and where to stay (Namba = food/nightlife, Umeda = convenient transit, Shin-Osaka = shinkansen access).
# - **Day 1 – Minami (Namba):** Kuromon Market (morning) → Shinsaibashi shopping → Dotonbori at night (canal walk + street food).
# - **Day 2 – Castle + Kita (Umeda):** Osaka Castle & park → Tenjinbashisuji shotengai → Umeda Sky Building / nightlife around Umeda.
# - **Day 3 – Culture & views:** Shitennoji Temple → Shinsekai (kushikatsu) → Abeno Harukas observatory (sunset).
# - **Day 4+ – Add-on day(s):** Universal Studios Japan **or** Aquarium (Kaiyukan) + Tempozan; optional day trips: Kyoto, Nara, Kobe, or Himeji (choose 1 per day)., source_executor_id=PlanningAgent)]
# [ExecutorCompletedEvent(executor_id=PlanningAgent, data=[AgentExecutorResponse(executor_id='PlanningAgent', agent_run_response=<agent_framework._types.AgentRunResponse object at 0x7522ed9439e0>, full_conversation=[<agent_framework._types.ChatMessage object at 0x75230ae43dd0>, <agent_framework._types.ChatMessage object at 0x75230a467ad0>]), <agent_framework._types.AgentRunResponse object at 0x75230a467140>])]
# [SuperStepStartedEvent(iteration=1, data=None)]
# [ExecutorInvokedEvent(executor_id=ReviseAgent, data=AgentExecutorResponse(executor_id='PlanningAgent', agent_run_response=<agent_framework._types.AgentRunResponse object at 0x7522e28dfa40>, full_conversation=[<agent_framework._types.ChatMessage object at 0x7522e26c6e70>, <agent_framework._types.ChatMessage object at 0x7522e28de6f0>]))]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=Dec)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ide)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= your)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= base)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= &)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= duration)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=:**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Stay)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= in)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=N)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=amba)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=food)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=/night)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=life)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=),)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=U)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=med)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=a)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=shopping)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=/)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=transport)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=),)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= or)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=Sh)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=in)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=Os)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=aka)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=day)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= trips)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=);)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= set)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= a)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= realistic)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= pace)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=2)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=–)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=4)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= main)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= stops)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=/day)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=).)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=
# )]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=Day)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= )]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=1)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= –)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Min)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ami)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=N)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=amba)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= area)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=):)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Ku)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=rom)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=on)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Market)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Sh)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=insa)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ib)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ashi)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=-s)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=uji)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= shopping)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= arcade)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= D)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=oton)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=bor)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=i)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= canal)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= +)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= night)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= street)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=-food)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= crawl)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=.)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=
# )]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=Day)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= )]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=2)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= –)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Castle)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= +)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Kita)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=U)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=med)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=a)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=):)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Osaka)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Castle)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=/)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=park)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Ten)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=jin)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=bash)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=isu)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ji)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Shopping)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Street)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= U)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=med)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=a)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Sky)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Building)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=sun)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=set)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=))]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= +)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= dinner)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= in)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Kita)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=.)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=
# )]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=Day)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= )]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=3)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= –)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Classic)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Osaka)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= vibes)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=:**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Sh)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=iten)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=no)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ji)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Shin)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=sek)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ai)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=/T)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=s)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=uten)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=k)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=aku)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=k)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ush)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ik)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=atsu)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=))]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= →)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= A)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ben)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=o)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Har)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ukas)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= observation)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= deck)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=even)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ing)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= view)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=).)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=
# )]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=-)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=Day)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= )]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=4)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=+)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= –)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Big)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ticket)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= or)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= day)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= trip)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=:**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=US)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=J)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= or)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=Os)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=aka)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Aquarium)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=Kai)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=y)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ukan)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=))]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= +)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Tempo)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=zan)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=;)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= optional)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= day)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= trips)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=:)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= **)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=Ky)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=oto)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=,)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= N)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ara)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=,)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= Kobe)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=,)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= H)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ime)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=ji)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=**)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= ()]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=pick)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= one)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= per)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages= day)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=).)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=)]
# [AgentRunUpdateEvent(executor_id=ReviseAgent, messages=)]
# [ExecutorCompletedEvent(executor_id=ReviseAgent, data=[AgentExecutorResponse(executor_id='ReviseAgent', agent_run_response=<agent_framework._types.AgentRunResponse object at 0x7522e28de690>, full_conversation=[<agent_framework._types.ChatMessage object at 0x75230ae43dd0>, <agent_framework._types.ChatMessage object at 0x75230a467ad0>, <agent_framework._types.ChatMessage object at 0x7522e28df500>])])]
# [SuperStepCompletedEvent(iteration=1, data=None)]
# [SuperStepStartedEvent(iteration=2, data=None)]
# [ExecutorInvokedEvent(executor_id=final_response_generator, data=AgentExecutorResponse(executor_id='ReviseAgent', agent_run_response=<agent_framework._types.AgentRunResponse object at 0x7522e2666210>, full_conversation=[<agent_framework._types.ChatMessage object at 0x7522e2666780>, <agent_framework._types.ChatMessage object at 0x7522e28dfb30>, <agent_framework._types.ChatMessage object at 0x7522e2666450>]))]
# [WorkflowOutputEvent(data=[<agent_framework._types.ChatMessage object at 0x75230ae43dd0>, <agent_framework._types.ChatMessage object at 0x75230a467ad0>, <agent_framework._types.ChatMessage object at 0x7522e28df500>], source_executor_id=final_response_generator)]
# [ExecutorCompletedEvent(executor_id=final_response_generator, data=[[<agent_framework._types.ChatMessage object at 0x7522e2666360>, <agent_framework._types.ChatMessage object at 0x7522e28def60>, <agent_framework._types.ChatMessage object at 0x7522e28de930>]])]
# [SuperStepCompletedEvent(iteration=2, data=None)]
# [WorkflowStatusEvent(state=WorkflowRunState.IDLE, data=None, origin=WorkflowEventSource.FRAMEWORK)]

# %% [markdown]
# ## 3. Checkpoint
#
# When you run a long-running workflow, it might need to suspend and restart it later.
# With checkpoint in workflow on Agent Framework, you can save (serialize) the state in the storage, and restore (deserialize) the state to resume the suspended instance.
#
# In this example, we explore checkpoint using ```InMemoryCheckpointStorage``` (non-persistent storage) for demo purpose.
#
# Checkpoint is created after each super step iteration internally.
# In this example, therefore, we suspend workflow when the first ```superstep_completed``` event is captured. And we then restore the checkpoint and resume the workflow.

# %% [markdown]
# First we generate a workflow again, with checkpoint enabled.
#
# > Note : When you need to restore custom data in your ```Executor```, please implement ```on_checkpoint_save()``` and ```on_checkpoint_restore()``` methods (override methods) in your custom executor class. (This example doesn't have such data.)

# %%
from agent_framework import InMemoryCheckpointStorage

# create checkpoint storage
checkpoint_storage = InMemoryCheckpointStorage()

# instantiate executor
planning_agent = Agent(
    name="PlanningAgent",
    client=client,
    instructions="Your task is to help users plan and concisely summarize it in five bullet points.",
)
revise_agent = Agent(
    name="ReviseAgent",
    client=client,
    instructions="Your task is to review the plan you receive and to refine it further.",
)
response_generator = ResponseGenerator(id="final_response_generator")

# build workflow
workflow_builder = (
    WorkflowBuilder(start_executor=planning_agent, checkpoint_storage=checkpoint_storage)
    .add_edge(planning_agent, revise_agent)
    .add_edge(revise_agent, response_generator)
)

# %% [markdown]
# Now let's run and suspend workflow as follows.
# As I have mentioned above, we suspend workflow when the first ```superstep_completed``` event is captured.
#
# **You may encounter an error (exception) when exiting the loop, but please ignore it.**

# %%
workflow = workflow_builder.build()

async for event in workflow.run("Create a plan for my travel in Osaka.", stream=True):
    # we suspend the workflow when the first superstep completion is captured
    if event.type == "superstep_completed":
        break

# %% [markdown]
# Let's get all checkpoints and show the number of all saved checkpoints.
# Here we have 2 checkpoints - the first checkpoint is initial checkpoint (which is saved if there are messages from initial execution) and the second is created after the first super step iteration.

# %%
checkpoints = await checkpoint_storage.list_checkpoints(workflow_name=workflow.name)
print(len(checkpoints))
# Out:
# 2

# %% [markdown]
# Now let's restore state by using checkpoint and resume workflow as follows.

# %%
workflow = workflow_builder.build()

final_checkpoint = checkpoints[-1]
events = await workflow.run(checkpoint_id=final_checkpoint.checkpoint_id)

# %% [markdown]
# Let's see the completed result (output) of this workflow.
# Even after suspended and resumed, the output is correctly generated.

# %%
outputs = events.get_outputs()
messages = outputs[0]
for i, (msg) in enumerate(messages, start=1):
    author_name = msg.author_name
    if author_name is None:
        author_name = "assistant" if msg.role == "assistant" else "user"
    print("----------------------------------")
    print(f"[{i:02d}: {author_name}]")
    print(msg.text)
# Out:
# ----------------------------------
# [01: user]
# Create a plan for my travel in Osaka.
# ----------------------------------
# [02: PlanningAgent]
# - **Set basics (dates, budget, base):** Pick travel dates/length, daily budget, and choose where to stay (best bases: **Namba/Shinsaibashi** for food/nightlife, **Umeda** for transport/hubs, **Tennoji** for value).
# - **Core areas by day:** Allocate days to **(1) Namba–Dotonbori–Shinsaibashi**, **(2) Osaka Castle + museum/parks**, **(3) Umeda (Sky Building) + shopping/food halls**, **(4) Bay Area: Kaiyukan Aquarium + Tempozan**, **(5) Shinsekai/Tennoji + Abeno Harukas**.
# - **Day trips (choose 1–2):** Add **Kyoto** (temples), **Nara** (deer + Todaiji), **Kobe** (harbor + beef), or **Himeji** (castle) based on interests and time.
# - **Food & reservations:** Plan key eats (takoyaki, okonomiyaki, kushikatsu, ramen, izakaya), make any must-visit reservations, and set a “street-food evening” around **Dotonbori**.
# - **Logistics checklist:** Get an **IC card (ICOCA)**, decide on any passes only if they save money, map transit for each day, pre-book popular tickets (e.g., **USJ** if going), and keep a flexible buffer block for rain/rest/shopping.
# ----------------------------------
# [03: ReviseAgent]
# - **Set your base & basics:** Choose dates/length, budget, and where to stay (best bases: **Namba/Shinsaibashi** for food/nightlife, **Umeda** for transport, **Tennoji** for value).
# - **Plan Osaka by zones (simple day structure):** **Day 1 Namba–Dotonbori–Shinsaibashi**, **Day 2 Osaka Castle + parks/museums**, **Day 3 Umeda (Sky Building) + shopping/food halls**, **Day 4 Bay Area (Kaiyukan + Tempozan)**, **Day 5 Tennoji/Shinsekai + Abeno Harukas**.
# - **Add 1–2 day trips (optional):** Pick based on interests: **Kyoto** (temples), **Nara** (deer + Todaiji), **Kobe** (harbor + food), **Himeji** (castle).
# - **Food plan & reservations:** Schedule one “street-food night” at **Dotonbori**, and list must-eats (takoyaki, okonomiyaki, kushikatsu, ramen, izakaya); reserve any must-visit restaurants.
# - **Logistics checklist:** Get an **IC card (ICOCA)**, only buy passes if they save money, prebook high-demand tickets (**USJ** if going), and keep a buffer block for rain/rest/shopping.
